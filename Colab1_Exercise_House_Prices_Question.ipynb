# %% [markdown]
# <a href="https://colab.research.google.com/github/jeewonb/coursera-tensorflow-certificate/blob/master/Colab1_Exercise_House_Prices_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])]) # Your Code Here#
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([1, 2, 3, 4, 5, 6, 7], dtype=int) # Your Code Here#
ys = np.array([1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0], dtype=float) # Your Code Here#
model.fit(xs, ys, epochs=500)
print(model.predict([7.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 673ms/step - loss: 62.1427
# Epoch 2/500
# 1/1 [==============================] - 0s 7ms/step - loss: 21.1861
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 7.2250
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4660
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8438
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2908
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1022
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0380
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0160
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0085
# Epoch 11/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0059
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0050
# ...
